# %% [raw]
# ---
# layout: post
# categories: [CSSE JavaScript]
# codemirror: true
# title: CS111 Project
# description: Comprehensive JavaScript project covering all CS111 rubric topics
# permalink: /js/cs111
# author: Aashi Hegu
# ---

# %% [markdown]
# # **CS111**

# %% [markdown]
# <div style="color: white; padding: 10px;">
#
# **Name:** <span style="color: red;">Aashi Hegu</span>
# **Grade:** <span style="color: red;">9th</span>
# **School:** <span style="color: red;">Del Norte</span>
# **Class:** <span style="color: red;">Computer Science 2</span>
# **Project:** <span style="color: red;">CS111</span>
#
# </div>

# %% [markdown]
# <div style="background: #0f3460; border-radius: 12px; padding: 20px; margin-bottom: 20px;">
#
# ## 🗂️ Rubric Coverage Map
#
# | CS111 Rubric Topic | Covered By | Status |
# |---|---|---|
# | 🔢 Data Types — Numbers | Variables, Math Expressions | ✅ |
# | 🔤 Data Types — Strings | Strings Homework | ✅ |
# | ✅ Data Types — Booleans | Boolean Homework | ✅ |
# | 📦 Data Types — Arrays | Arrays, Array Hack, Data Abstraction | ✅ |
# | 🗃️ Data Types — JSON Objects | Data Abstraction | ✅ |
# | ➕ Operators — Mathematical | Math Expressions | ✅ |
# | 🔗 Operators — String | Strings Homework | ✅ |
# | ⚖️ Operators — Boolean | Boolean Homework | ✅ |
# | 🔁 Control Structures — Iteration | Iteration Homework | ✅ |
# | 🔀 Control Structures — Conditions | Boolean, Functions | ✅ |
# | 🏗️ Classes & OOP | Classes & Constructors, Classes & Variables | ✅ |
# | ⚙️ Methods & Parameters | Functions, Classes & Constructors | ✅ |
#
# </div>

# %% [markdown]
# ---
#
# <div style="background: linear-gradient(135deg, #667eea 0%, #764ba2 100%); padding: 30px; border-radius: 15px; color: white; text-align: center; margin: 30px 0;">
#   <h1 style="color: white; margin: 0;">🖥️ Computer Science 1-2</h1>
#   <p style="font-size: 16px;">Trimester Highlights & Portfolio</p>
# </div>

# %% [markdown]
# <div style="display: flex; gap: 15px; flex-wrap: wrap; margin-bottom: 20px;">
#
# <div style="flex: 1; min-width: 280px; background: linear-gradient(135deg, #f093fb 0%, #f5576c 100%); border-radius: 12px; padding: 20px;">
#
# ### 📘 Trimester 1
#
# <font color="white">
#
# **Coming soon!** This section will cover:
#
# - 🔧 Tools & Setup
# - 🌐 HTML/CSS Fundamentals
# - 📜 JavaScript Basics
# - 🎮 Sprite Animations
# - 🧩 Game Development
# - 📦 Version Control with Git
#
# </font>
#
# <button style="background: white; color: #f5576c; border: none; padding: 10px 20px; border-radius: 8px; font-weight: bold; cursor: pointer; margin-top: 10px;">📂 View Tri 1 Work</button>
#
# </div>
#
# <div style="flex: 1; min-width: 280px; background: linear-gradient(135deg, #4facfe 0%, #00f2fe 100%); border-radius: 12px; padding: 20px;">
#
# ### 📗 Trimester 2
#
# <font color="white">
#
# **Coming soon!** This section will cover:
#
# - 🔢 Data Types Deep Dive
# - 🔁 Loops & Iteration
# - 🏗️ Classes & OOP
# - 🗃️ Data Abstraction
# - ⚙️ Functions & Methods
# - 🚀 Full Stack Projects
#
# </font>
#
# <button style="background: white; color: #4facfe; border: none; padding: 10px 20px; border-radius: 8px; font-weight: bold; cursor: pointer; margin-top: 10px;">📂 View Tri 2 Work</button>
#
# </div>
#
# </div>

# %% [markdown]
# ---
#
# <div style="background: linear-gradient(135deg, #11998e 0%, #38ef7d 100%); padding: 20px; border-radius: 15px; text-align: center; margin-top: 20px;">
#   <h2 style="color: white; margin: 0;">🎉 CS111 Project Complete!</h2>
#   <p style="color: white; font-size: 16px;">By Aashi Hegu | Grade 9 | Del Norte | Computer Science 2</p>
#   <p style="color: white;">✅ All 12 rubric topics covered!</p>
# </div>
